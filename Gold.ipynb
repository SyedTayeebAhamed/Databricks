# %% [markdown]
# ### Reading data from the silver --> Gold

# %%
df=spark.read.table("workspace.raw_data_taxi.silver_taxi_data")

# %% [markdown]
# # Defining star schema

# %% [markdown]
# ### Dimension of date

# %%
from pyspark.sql.functions import col, date_format, month, year, dayofweek,unix_date


dim_date = df.select("trip_date").distinct() \
     .withColumn("date_key", unix_date(col("trip_date"))) \
    .withColumn("day_of_week", date_format(col("trip_date"), "E")) \
    .withColumn("month", month(col("trip_date"))) \
    .withColumn("year", year(col("trip_date"))) \
    .withColumn("is_weekend", (dayofweek(col("trip_date")) >= 6).cast("boolean"))

# %% [markdown]
# ### Dimension table of vendorID

# %%
from pyspark.sql.functions import monotonically_increasing_id

dim_vendor = df.select("vendorID").distinct() \
    .withColumn("vendor_key", monotonically_increasing_id())

# %% [markdown]
# ### Dimension table of Payments

# %%
dim_payment = df.select(
    col("payment_type").alias("payment_type_code"),
    col("payment_type_normalized")
).distinct() \
.withColumn("payment_key", monotonically_increasing_id())

# %% [markdown]
# ### Dimension table of locations

# %%
dim_location = df.select(
    col("PULocationID").alias("LocationID")
).union(
    df.select(col("DOLocationID").alias("LocationID"))
).distinct() \
.withColumn("location_key", monotonically_increasing_id())

# %% [markdown]
# ### Joining fact tables and dimension tables

# %%
from pyspark.sql.functions import col

# Alias each DataFrame
df_base = df.alias("f")
dim_date_a = dim_date.alias("d")
dim_vendor_a = dim_vendor.alias("v")
dim_payment_a = dim_payment.alias("p")
dim_location_a = dim_location.alias("l")

# Build fact table with qualified column references
fact_trips = df_base \
    .join(dim_date_a, col("f.trip_date") == col("d.trip_date"), "left") \
    .join(dim_vendor_a, col("f.vendorID") == col("v.vendorID"), "left") \
    .join(dim_payment_a, col("f.payment_type_normalized") == col("p.payment_type_normalized"), "left") \
    .join(dim_location_a, col("f.PULocationID") == col("l.LocationID"), "left") \
    .select(
        col("f.trip_id"),
        col("d.date_key"),
        col("v.vendor_key"),
        col("p.payment_key"),
        col("l.location_key").alias("pickup_location_key"),
        col("f.trip_distance"),
        col("f.trip_duration_minutes"),
        col("f.passenger_count"),
        col("f.fare_amount"),
        col("f.tip_amount"),
        col("f.total_amount")
    )

# %% [markdown]
# ###  Save latest_ts into a metadata table for incremental load

# %%
latest_ts = df_base.selectExpr("max(tpep_pickup_datetime)").collect()[0][0]
# Save latest_ts into a metadata table for incremental loads

# %%
fact_trips = fact_trips.dropDuplicates(["trip_id"])

# %%
fact_trips.write.mode("overwrite").format("delta").partitionBy("date_key").saveAsTable("gold.fact_trips")
dim_date.write.mode("overwrite").format("delta").saveAsTable("gold.dim_date")
dim_vendor.write.mode("overwrite").format("delta").saveAsTable("gold.dim_vendor")
dim_payment.write.mode("overwrite").format("delta").saveAsTable("gold.dim_payment")
dim_location.write.mode("overwrite").format("delta").saveAsTable("gold.dim_location")

# %% [markdown]
# ### Merging the latest data

# %%
from delta.tables import DeltaTable

fact_table = DeltaTable.forName(spark, "gold.fact_trips")

fact_table.alias("t").merge(
    fact_trips.alias("s"),
    "t.trip_id = s.trip_id"
).whenMatchedUpdateAll() \
 .whenNotMatchedInsertAll() \
 .execute()
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %% [markdown]
# ### Overwrite the fact and dimension table

# %%
# %sql
select * from gold.dim_date
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>trip_date</th><th>date_key</th><th>day_of_week</th><th>month</th><th>year</th><th>is_weekend</th></tr></thead><tbody><tr><td>2020-12-31</td><td>18627</td><td>Thu</td><td>12</td><td>2020</td><td>false</td></tr><tr><td>2021-01-01</td><td>18628</td><td>Fri</td><td>1</td><td>2021</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
select * from gold.fact_trips
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>trip_id</th><th>date_key</th><th>vendor_key</th><th>payment_key</th><th>pickup_location_key</th><th>trip_distance</th><th>trip_duration_minutes</th><th>passenger_count</th><th>fare_amount</th><th>tip_amount</th><th>total_amount</th></tr></thead><tbody><tr><td>008c503251cfd929305b21e4698fca64b3b59ed966e72fadb62e26d2266a9f46</td><td>18628</td><td>0</td><td>3</td><td>10</td><td>3.6</td><td>18.87</td><td>1</td><td>15.0</td><td>4.7</td><td>23.5</td></tr><tr><td>00abdead617377b6d2d2aa53c7c86c38bfdc4def6093131e6d066a655d5b7e10</td><td>18628</td><td>0</td><td>3</td><td>58</td><td>1.21</td><td>7.15</td><td>2</td><td>7.0</td><td>2.49</td><td>10.79</td></tr><tr><td>00e73106c67c2bac2d125abf1a45ef039257636c5295eb48d4885512820f3a35</td><td>18628</td><td>1</td><td>3</td><td>46</td><td>4.1</td><td>14.43</td><td>1</td><td>14.5</td><td>5.45</td><td>23.75</td></tr><tr><td>00f7629efe20dd3684449e4d278ba7e558b6aa11e4369a45866e93c72ac22f11</td><td>18628</td><td>0</td><td>3</td><td>39</td><td>1.99</td><td>12.47</td><td>1</td><td>10.0</td><td>2.76</td><td>16.56</td></tr><tr><td>0171352ea7422396adbf923b69700fbbeb7f6b98cd544ef8a5193acc71aadcf3</td><td>18628</td><td>0</td><td>3</td><td>59</td><td>3.79</td><td>12.48</td><td>2</td><td>13.0</td><td>5.04</td><td>21.84</td></tr><tr><td>0211e2d4bf05ede820868d170c8a14e01ad235b263a93eb24b201702663ec933</td><td>18628</td><td>0</td><td>2</td><td>16</td><td>1.96</td><td>7.25</td><td>2</td><td>8.0</td><td>0</td><td>11.8</td></tr><tr><td>02244aed8ff0ac97fdf91872425216aeb251212f88426c1c5d7f6240fdf19559</td><td>18628</td><td>0</td><td>3</td><td>21</td><td>0.74</td><td>3.73</td><td>1</td><td>5.0</td><td>0</td><td>8.8</td></tr><tr><td>029b4d924846f8df8369207b8c9b3c17e90b4b721c5830060e42845aa5803d16</td><td>18628</td><td>0</td><td>3</td><td>10</td><td>4.17</td><td>15.65</td><td>1</td><td>15.0</td><td>0</td><td>18.8</td></tr><tr><td>02e8545cc8245a7ad0da72ea1a3089f3c76aab6a17f647c5b0050e1321dc8fbd</td><td>18628</td><td>1</td><td>2</td><td>62</td><td>1.2</td><td>6.82</td><td>1</td><td>7.0</td><td>0</td><td>8.3</td></tr><tr><td>034d885644be9a2988af32f4b958e4092db7b0f6b490dac39bf3ab4fcb80830d</td><td>18628</td><td>0</td><td>3</td><td>72</td><td>3.06</td><td>11.87</td><td>1</td><td>11.5</td><td>1</td><td>16.3</td></tr><tr><td>037c846576dff1676266c50d17e7e933924d2b039893615f14772e8612bc48a8</td><td>18628</td><td>0</td><td>2</td><td>31</td><td>0.76</td><td>3.73</td><td>1</td><td>5.0</td><td>0</td><td>8.8</td></tr><tr><td>03989649d879481c356d62c5f332b5c0c06e7be2f1576f3e8c59e77d849c33ff</td><td>18628</td><td>0</td><td>3</td><td>69</td><td>0.93</td><td>3.4</td><td>1</td><td>5.0</td><td>1</td><td>9.8</td></tr><tr><td>0447b892090dbb8f8e33cbae3d52e58d90baeeff70e3eacb4ffe799f656ce7a8</td><td>18628</td><td>0</td><td>3</td><td>6</td><td>3.17</td><td>13.1</td><td>1</td><td>12.0</td><td>2.8</td><td>18.6</td></tr><tr><td>0495bd91deb00e6e76edac8a0e2a2dbb53cf12c2e57900cd2bec86fd60a28e9b</td><td>18628</td><td>0</td><td>2</td><td>50</td><td>0.49</td><td>5.22</td><td>1</td><td>5.0</td><td>0</td><td>8.8</td></tr><tr><td>04aad389c910c3ddf60d363eb9a9490697429982c23cc2e9c236a4663903d5d7</td><td>18628</td><td>0</td><td>3</td><td>27</td><td>0.88</td><td>7.7</td><td>6</td><td>6.5</td><td>1.54</td><td>11.84</td></tr><tr><td>04fb1d6ab896eac451675819934b8bd939f986560770ed1fd9276ddfecaeb5b6</td><td>18628</td><td>0</td><td>2</td><td>18</td><td>12.88</td><td>28.9</td><td>1</td><td>37.5</td><td>0</td><td>41.3</td></tr><tr><td>0501dc296e9d8be79d465fc71ea3fe3d48f7717b53e4dba8eee6edcfa388e5bb</td><td>18628</td><td>1</td><td>3</td><td>44</td><td>3.2</td><td>11.78</td><td>1</td><td>11.5</td><td>4.4</td><td>19.2</td></tr><tr><td>050355474e031d85541d0b9165d273341f7a429dcba5560959caf97559d850cd</td><td>18628</td><td>0</td><td>3</td><td>70</td><td>1.55</td><td>8.02</td><td>1</td><td>7.5</td><td>2.82</td><td>14.12</td></tr><tr><td>051b03fef75936d32423c0 ...
